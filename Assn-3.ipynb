# %% [markdown]
# # Assn-3
#
# This is a test to check notebook rendering on GitHub.

# %%
import numpy as np
import matplotlib.pyplot as plt

y = np.array( [0, 5, 2, 8, 1] )

plt.figure()
plt.plot( y )
plt.show()
